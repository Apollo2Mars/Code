# %%
text = """指示灯
味道
运转音
净化效果
风量
电源
尺寸
感应
设计
滤芯滤网
模式
操作
包装
显示
功能
价保
发票
商品复购
商品用途
商品价格
商品质量
商品颜色
商品外观
商品营销
商品品牌
商品产地
商品其他
客服态度
客服处理速度
客服其他
配送速度
物流态度
物流其他
维修服务
安装服务
退货服务
换货服务
质保
退款服务
售后其他"""

# print(text)
print(len(text.split('\n')))
print(text.split('\n'))
#for line in text:
#    print(line)
# Out:
# 40
# ['指示灯', '味道', '运转音', '净化效果', '风量', '电源', '尺寸', '感应', '设计', '滤芯滤网', '模式', '操作', '包装', '显示', '功能', '价保', '发票', '商品复购', '商品用途', '商品价格', '商品质量', '商品颜色', '商品外观', '商品营销', '商品品牌', '商品产地', '商品其他', '客服态度', '客服处理速度', '客服其他', '配送速度', '物流态度', '物流其他', '维修服务', '安装服务', '退货服务', '换货服务', '质保', '退款服务', '售后其他']

# %%
text = """剃须方式
配件
刀头刀片
清洁方式
剃须效果
充电
续航
运转音
包装
显示
尺寸
价保
商品复购
商品用途
商品价格
商品质量
商品颜色
商品外观
商品营销
商品品牌
商品产地
商品其他
客服态度
客服处理速度
客服其他
配送速度
物流态度
物流其他
维修服务
退货服务
换货服务
质保
退款服务
售后其他"""

# print(text)
print(len(text.split('\n')))
print(text.split('\n'))
#for line in text:
#    print(line)
# Out:
# 34
# ['剃须方式', '配件', '刀头刀片', '清洁方式', '剃须效果', '充电', '续航', '运转音', '包装', '显示', '尺寸', '价保', '商品复购', '商品用途', '商品价格', '商品质量', '商品颜色', '商品外观', '商品营销', '商品品牌', '商品产地', '商品其他', '客服态度', '客服处理速度', '客服其他', '配送速度', '物流态度', '物流其他', '维修服务', '退货服务', '换货服务', '质保', '退款服务', '售后其他']

# %%
text="""P-E-Mode	剃须方式
P-E-Fittings	配件
P-E-Blade	刀头刀片
P-E-Cleaning	清洁方式
P-E-Effect	剃须效果
P-E-Charge	充电
P-E-Endurance	续航
P-E-Sound	运转音
P-E-Packing	包装
P-E-Screen	显示
P-E-Size	尺寸
P-E-PriceMatch	价保
P-C-Loyalty	商品复购
P-C-Use	商品用途
P-C-Price	商品价格
P-C-Quality	商品质量
P-C-Color	商品颜色
P-C-Appearance	商品外观
P-C-Marketing	商品营销
P-C-Brand	商品品牌
P-C-Origin	商品产地
P-C-Others	商品其他
CS-C-Attitude	客服态度
CS-C-Handling	客服处理速度
CS-C-Others	客服其他
L-C-Delivery	配送速度
L-C-Attitude	物流态度
L-C-Others	物流其他
S-C-Maintanence	维修服务
S-C-Return	退货服务
S-C-Exchange	换货服务
S-C-Warranty	质保
S-C-Refund	退款服务
S-C-Others	售后其他"""

print(len(text.split('\n')))
result_list = text.split('\n')

dict_1 = {}
for item in result_list:
    print(item)
    key = item.split('\t')[0].lower()
    value = item.split('\t')[1]
    dict_1[key] = value
print(dict_1)
# Out:
# 34
# P-E-Mode	剃须方式
# P-E-Fittings	配件
# P-E-Blade	刀头刀片
# P-E-Cleaning	清洁方式
# P-E-Effect	剃须效果
# P-E-Charge	充电
# P-E-Endurance	续航
# P-E-Sound	运转音
# P-E-Packing	包装
# P-E-Screen	显示
# P-E-Size	尺寸
# P-E-PriceMatch	价保
# P-C-Loyalty	商品复购
# P-C-Use	商品用途
# P-C-Price	商品价格
# P-C-Quality	商品质量
# P-C-Color	商品颜色
# P-C-Appearance	商品外观
# P-C-Marketing	商品营销
# P-C-Brand	商品品牌
# P-C-Origin	商品产地
# P-C-Others	商品其他
# CS-C-Attitude	客服态度
# CS-C-Handling	客服处理速度
# CS-C-Others	客服其他
# L-C-Delivery	配送速度
# L-C-Attitude	物流态度
# L-C-Others	物流其他
# S-C-Maintanence	维修服务
# S-C-Return	退货服务
# S-C-Exchange	换货服务
# S-C-Warranty	质保
# S-C-Refund	退款服务
# S-C-Others	售后其他
# ...

# %%
text="""P-E-Mode
P-E-Fittings
P-E-Blade
P-E-Cleaning
P-E-Effect
P-E-Charge
P-E-Endurance
P-E-Sound
P-E-Packing
P-E-Screen
P-E-Size
P-E-PriceMatch
P-C-Loyalty
P-C-Use
P-C-Price
P-C-Quality
P-C-Color
P-C-Appearance
P-C-Marketing
P-C-Brand
P-C-Origin
P-C-Others
CS-C-Attitude
CS-C-Handling
CS-C-Others
L-C-Delivery
L-C-Attitude
L-C-Others
S-C-Maintanence
S-C-Return
S-C-Exchange
S-C-Warranty
S-C-Refund
S-C-Others"""
print(len(text.split('\n')))
result_list = text.split('\n')

list_1 = []
for item in result_list:
    print(item)
    key = item.split('\t')[0].lower()
    list_1.append(key)
print(list_1)
# Out:
# 34
# P-E-Mode
# P-E-Fittings
# P-E-Blade
# P-E-Cleaning
# P-E-Effect
# P-E-Charge
# P-E-Endurance
# P-E-Sound
# P-E-Packing
# P-E-Screen
# P-E-Size
# P-E-PriceMatch
# P-C-Loyalty
# P-C-Use
# P-C-Price
# P-C-Quality
# P-C-Color
# P-C-Appearance
# P-C-Marketing
# P-C-Brand
# P-C-Origin
# P-C-Others
# CS-C-Attitude
# CS-C-Handling
# CS-C-Others
# L-C-Delivery
# L-C-Attitude
# L-C-Others
# S-C-Maintanence
# S-C-Return
# S-C-Exchange
# S-C-Warranty
# S-C-Refund
# S-C-Others
# ['p-e-mode', 'p-e-fittings', 'p-e-blade', 'p-e-cleaning', 'p-e-effect', 'p-e-charge', 'p-e-endurance', 'p-e-sound', 'p-e-packing', 'p-e-screen', 'p-e-size', 'p-e-pricematch', 'p-c-loyalty', 'p-c-use', 'p-c-price', 'p-c-quality', 'p-c-color', 'p-c-appearance', 'p-c-marketing', 'p-c-brand', 'p-c-origin', 'p-c-others', 'cs-c-attitude', 'cs-c-handling', 'cs-c-others', 'l-c-delivery', 'l-c-attitude', 'l-c-others', 's-c-maintanence', 's-c-return', 's-c-exchange', 's-c-warranty', 's-c-refund', 's-c-others']

# %%
text = """Sentiment-Positibve
Sentiment-Negative
Sentiment-Moderate"""
result_list = text.split('\n')

list_1 = []
for item in result_list:
    print(item)
    key = item.split('\t')[0].lower()
    list_1.append(key)
print(list_1)
# Out:
# Sentiment-Positibve
# Sentiment-Negative
# Sentiment-Moderate
# ['sentiment-positibve', 'sentiment-negative', 'sentiment-moderate']

# %%
text="""P-E-Type	牙刷类型
P-E-Mode	刷牙模式
P-E-Brush Head	刷头
P-E-Fittings	配件
P-E-Function	智能功效
P-E-BaseFunction	牙刷功能
P-E-Effect	刷牙效果
P-E-Charge	充电
P-E-Endurance	续航
P-E-Power	动力
P-E-Sound	运转音
P-E-Packing	包装
P-E-Screen	显示
P-E-Size	尺寸
P-E-PriceMatch	价保
P-C-Loyalty	商品复购
P-C-Use	商品用途
P-C-Price	商品价格
P-C-Quality	商品质量
P-C-Color	商品颜色
P-C-Appearance	商品外观
P-C-Marketing	商品营销
P-C-Brand	商品品牌
P-C-Origin	商品产地
P-C-Others	商品其他
CS-C-Attitude	客服态度
CS-C-Handling	客服处理速度
CS-C-Others	客服其他
L-C-Delivery	配送速度
L-C-Attitude	物流态度
L-C-Others	物流其他
S-C-Maintanence	维修服务
S-C-Return	退货服务
S-C-Exchange	换货服务
S-C-Warranty	质保
S-C-Refund	退款服务
S-C-Others	售后其他"""

print(len(text.split('\n')))
result_list = text.split('\n')

dict_1 = {}
for item in result_list:
    print(item)
    key = item.split('\t')[0].lower()
    value = item.split('\t')[1]
    dict_1[key] = value
print(dict_1)
# Out:
# 37
# P-E-Type	牙刷类型
# P-E-Mode	刷牙模式
# P-E-Brush Head	刷头
# P-E-Fittings	配件
# P-E-Function	智能功效
# P-E-BaseFunction	牙刷功能
# P-E-Effect	刷牙效果
# P-E-Charge	充电
# P-E-Endurance	续航
# P-E-Power	动力
# P-E-Sound	运转音
# P-E-Packing	包装
# P-E-Screen	显示
# P-E-Size	尺寸
# P-E-PriceMatch	价保
# P-C-Loyalty	商品复购
# P-C-Use	商品用途
# P-C-Price	商品价格
# P-C-Quality	商品质量
# P-C-Color	商品颜色
# P-C-Appearance	商品外观
# P-C-Marketing	商品营销
# P-C-Brand	商品品牌
# P-C-Origin	商品产地
# P-C-Others	商品其他
# CS-C-Attitude	客服态度
# CS-C-Handling	客服处理速度
# CS-C-Others	客服其他
# L-C-Delivery	配送速度
# L-C-Attitude	物流态度
# L-C-Others	物流其他
# S-C-Maintanence	维修服务
# S-C-Return	退货服务
# S-C-Exchange	换货服务
# S-C-Warranty	质保
# S-C-Refund	退款服务
# S-C-Others	售后其他
# ...

# %%
text="""P-E-Type	牙刷类型
P-E-Mode	刷牙模式
P-E-Brush Head	刷头
P-E-Fittings	配件
P-E-Function	智能功效
P-E-BaseFunction	牙刷功能
P-E-Effect	刷牙效果
P-E-Charge	充电
P-E-Endurance	续航
P-E-Power	动力
P-E-Sound	运转音
P-E-Packing	包装
P-E-Screen	显示
P-E-Size	尺寸
P-E-PriceMatch	价保
P-C-Loyalty	商品复购
P-C-Use	商品用途
P-C-Price	商品价格
P-C-Quality	商品质量
P-C-Color	商品颜色
P-C-Appearance	商品外观
P-C-Marketing	商品营销
P-C-Brand	商品品牌
P-C-Origin	商品产地
P-C-Others	商品其他
CS-C-Attitude	客服态度
CS-C-Handling	客服处理速度
CS-C-Others	客服其他
L-C-Delivery	配送速度
L-C-Attitude	物流态度
L-C-Others	物流其他
S-C-Maintanence	维修服务
S-C-Return	退货服务
S-C-Exchange	换货服务
S-C-Warranty	质保
S-C-Refund	退款服务
S-C-Others	售后其他"""
print(len(text.split('\n')))
result_list = text.split('\n')

dict_1 = {}
for item in result_list:
    print(item)
    key = item.split('\t')[0].lower()
    value = item.split('\t')[1]
    dict_1[key] = value
print(dict_1)
# Out:
# 37
# P-E-Type	牙刷类型
# P-E-Mode	刷牙模式
# P-E-Brush Head	刷头
# P-E-Fittings	配件
# P-E-Function	智能功效
# P-E-BaseFunction	牙刷功能
# P-E-Effect	刷牙效果
# P-E-Charge	充电
# P-E-Endurance	续航
# P-E-Power	动力
# P-E-Sound	运转音
# P-E-Packing	包装
# P-E-Screen	显示
# P-E-Size	尺寸
# P-E-PriceMatch	价保
# P-C-Loyalty	商品复购
# P-C-Use	商品用途
# P-C-Price	商品价格
# P-C-Quality	商品质量
# P-C-Color	商品颜色
# P-C-Appearance	商品外观
# P-C-Marketing	商品营销
# P-C-Brand	商品品牌
# P-C-Origin	商品产地
# P-C-Others	商品其他
# CS-C-Attitude	客服态度
# CS-C-Handling	客服处理速度
# CS-C-Others	客服其他
# L-C-Delivery	配送速度
# L-C-Attitude	物流态度
# L-C-Others	物流其他
# S-C-Maintanence	维修服务
# S-C-Return	退货服务
# S-C-Exchange	换货服务
# S-C-Warranty	质保
# S-C-Refund	退款服务
# S-C-Others	售后其他
# ...

# %%
text = """牙刷类型
刷牙模式
刷头
配件
智能功效
牙刷功能
刷牙效果
充电
续航
动力
运转音
包装
显示
尺寸
价保
商品复购
商品用途
商品价格
商品质量
商品颜色
商品外观
商品营销
商品品牌
商品产地
商品其他
客服态度
客服处理速度
客服其他
配送速度
物流态度
物流其他
维修服务
退货服务
换货服务
质保
退款服务
售后其他"""

# print(text)
print(len(text.split('\n')))
print(text.split('\n'))
#for line in text:
#    print(line)
# Out:
# 37
# ['牙刷类型', '刷牙模式', '刷头', '配件', '智能功效', '牙刷功能', '刷牙效果', '充电', '续航', '动力', '运转音', '包装', '显示', '尺寸', '价保', '商品复购', '商品用途', '商品价格', '商品质量', '商品颜色', '商品外观', '商品营销', '商品品牌', '商品产地', '商品其他', '客服态度', '客服处理速度', '客服其他', '配送速度', '物流态度', '物流其他', '维修服务', '退货服务', '换货服务', '质保', '退款服务', '售后其他']

# %%
text = """P-E-Type
P-E-Mode
P-E-Brush Head
P-E-Fittings
P-E-Function
P-E-BaseFunction
P-E-Effect
P-E-Charge
P-E-Endurance
P-E-Power
P-E-Sound
P-E-Packing
P-E-Screen
P-E-Size
P-E-PriceMatch
P-C-Loyalty
P-C-Use
P-C-Price
P-C-Quality
P-C-Color
P-C-Appearance
P-C-Marketing
P-C-Brand
P-C-Origin
P-C-Others
CS-C-Attitude
CS-C-Handling
CS-C-Others
L-C-Delivery
L-C-Attitude
L-C-Others
S-C-Maintanence
S-C-Return
S-C-Exchange
S-C-Warranty
S-C-Refund
S-C-Others"""

print(len(text.split('\n')))
result_list = text.split('\n')

list_1 = []
for item in result_list:
    print(item)
    key = item.split('\t')[0].lower()
    list_1.append(key)
print(list_1)
# Out:
# 37
# P-E-Type
# P-E-Mode
# P-E-Brush Head
# P-E-Fittings
# P-E-Function
# P-E-BaseFunction
# P-E-Effect
# P-E-Charge
# P-E-Endurance
# P-E-Power
# P-E-Sound
# P-E-Packing
# P-E-Screen
# P-E-Size
# P-E-PriceMatch
# P-C-Loyalty
# P-C-Use
# P-C-Price
# P-C-Quality
# P-C-Color
# P-C-Appearance
# P-C-Marketing
# P-C-Brand
# P-C-Origin
# P-C-Others
# CS-C-Attitude
# CS-C-Handling
# CS-C-Others
# L-C-Delivery
# L-C-Attitude
# L-C-Others
# S-C-Maintanence
# S-C-Return
# S-C-Exchange
# S-C-Warranty
# S-C-Refund
# S-C-Others
# ...

# %%
text="""P-E-Type	吸尘器类型
P-E-Mode	运行模式
P-E-Sucker	吸头/吸嘴/刷头
P-E-Fittings	配件
P-E-Function	智能功能
P-E-Effect	效果
P-E-Strainer	滤芯滤网
P-E-Charge	充电
P-E-Endurance	续航
P-E-Power	吸力
P-E-Sound	运转音
P-E-Packing	包装
P-E-Screen	显示
P-E-Size	尺寸
P-E-PriceMatch	价保
P-E-Use	商品用途
P-E-Environment	商品使用环境场景
P-C-Loyalty	商品复购
P-C-Price	商品价格
P-C-Quality	商品质量
P-C-Color	商品颜色
P-C-Appearance	商品外观
P-C-Marketing	商品营销
P-C-Brand	商品品牌
P-C-Origin	商品产地
P-C-Others	商品其他
CS-C-Attitude	客服态度
CS-C-Handling	客服处理速度
CS-C-Others	客服其他
L-C-Delivery	配送速度
L-C-Attitude	物流态度
L-C-Others	物流其他
S-C-Maintanence	维修服务
S-C-Return	退货服务
S-C-Exchange	换货服务
S-C-Warranty	质保
S-C-Refund	退款服务
S-C-Others	售后其他"""

print(len(text.split('\n')))
result_list = text.split('\n')

dict_1 = {}
for item in result_list:
    print(item)
    key = item.split('\t')[0].lower()
    value = item.split('\t')[1]
    dict_1[key] = value
print(dict_1)
# Out:
# 38
# P-E-Type	吸尘器类型
# P-E-Mode	运行模式
# P-E-Sucker	吸头/吸嘴/刷头
# P-E-Fittings	配件
# P-E-Function	智能功能
# P-E-Effect	效果
# P-E-Strainer	滤芯滤网
# P-E-Charge	充电
# P-E-Endurance	续航
# P-E-Power	吸力
# P-E-Sound	运转音
# P-E-Packing	包装
# P-E-Screen	显示
# P-E-Size	尺寸
# P-E-PriceMatch	价保
# P-E-Use	商品用途
# P-E-Environment	商品使用环境场景
# P-C-Loyalty	商品复购
# P-C-Price	商品价格
# P-C-Quality	商品质量
# P-C-Color	商品颜色
# P-C-Appearance	商品外观
# P-C-Marketing	商品营销
# P-C-Brand	商品品牌
# P-C-Origin	商品产地
# P-C-Others	商品其他
# CS-C-Attitude	客服态度
# CS-C-Handling	客服处理速度
# CS-C-Others	客服其他
# L-C-Delivery	配送速度
# L-C-Attitude	物流态度
# L-C-Others	物流其他
# S-C-Maintanence	维修服务
# S-C-Return	退货服务
# S-C-Exchange	换货服务
# S-C-Warranty	质保
# S-C-Refund	退款服务
# S-C-Others	售后其他
# ...

# %%
text="""吸尘器类型
运行模式
吸头/吸嘴/刷头
配件
智能功能
效果
滤芯滤网
充电
续航
吸力
运转音
包装
显示
尺寸
价保
商品用途
商品使用环境场景
商品复购
商品价格
商品质量
商品颜色
商品外观
商品营销
商品品牌
商品产地
商品其他
客服态度
客服处理速度
客服其他
配送速度
物流态度
物流其他
维修服务
退货服务
换货服务
质保
退款服务
售后其他"""

print(len(text.split('\n')))
print(text.split('\n'))
# Out:
# 38
# ['吸尘器类型', '运行模式', '吸头/吸嘴/刷头', '配件', '智能功能', '效果', '滤芯滤网', '充电', '续航', '吸力', '运转音', '包装', '显示', '尺寸', '价保', '商品用途', '商品使用环境场景', '商品复购', '商品价格', '商品质量', '商品颜色', '商品外观', '商品营销', '商品品牌', '商品产地', '商品其他', '客服态度', '客服处理速度', '客服其他', '配送速度', '物流态度', '物流其他', '维修服务', '退货服务', '换货服务', '质保', '退款服务', '售后其他']

# %%
text = """P-E-Type
P-E-Mode
P-E-Sucker
P-E-Fittings
P-E-Function
P-E-Effect
P-E-Strainer
P-E-Charge
P-E-Endurance
P-E-Power
P-E-Sound
P-E-Packing
P-E-Screen
P-E-Size
P-E-PriceMatch
P-E-Use
P-E-Environment
P-C-Loyalty
P-C-Price
P-C-Quality
P-C-Color
P-C-Appearance
P-C-Marketing
P-C-Brand
P-C-Origin
P-C-Others
CS-C-Attitude
CS-C-Handling
CS-C-Others
L-C-Delivery
L-C-Attitude
L-C-Others
S-C-Maintanence
S-C-Return
S-C-Exchange
S-C-Warranty
S-C-Refund
S-C-Others"""

print(len(text.split('\n')))
result_list = text.split('\n')

list_1 = []
for item in result_list:
    print(item)
    key = item.split('\t')[0].lower()
    list_1.append(key)
print(list_1)
# Out:
# 38
# P-E-Type
# P-E-Mode
# P-E-Sucker
# P-E-Fittings
# P-E-Function
# P-E-Effect
# P-E-Strainer
# P-E-Charge
# P-E-Endurance
# P-E-Power
# P-E-Sound
# P-E-Packing
# P-E-Screen
# P-E-Size
# P-E-PriceMatch
# P-E-Use
# P-E-Environment
# P-C-Loyalty
# P-C-Price
# P-C-Quality
# P-C-Color
# P-C-Appearance
# P-C-Marketing
# P-C-Brand
# P-C-Origin
# P-C-Others
# CS-C-Attitude
# CS-C-Handling
# CS-C-Others
# L-C-Delivery
# L-C-Attitude
# L-C-Others
# S-C-Maintanence
# S-C-Return
# S-C-Exchange
# S-C-Warranty
# S-C-Refund
# S-C-Others
# ...

# %%
text="""P-E-Type
P-E-Cleaning
P-E-Fittings
P-E-Operation
P-E-Function
P-E-Visualization
P-E-Effect
P-E-Sound
P-E-Packing
P-E-Screen
P-E-Size
P-E-PriceMatch
P-E-RelatedCategories
P-C-Loyalty
P-C-Use
P-C-Price
P-C-Quality
P-C-Color
P-C-Appearance
P-C-Marketing
P-C-Brand
P-C-Origin
P-C-Others
CS-C-Attitude
CS-C-Handling
CS-C-Others
L-C-Delivery
L-C-Attitude
L-C-Others
S-C-Maintanence
S-C-Return
S-C-Exchange
S-C-Warranty
S-C-Refund
S-C-Others"""
print(len(text.split('\n')))
result_list = text.split('\n')

list_1 = []
for item in result_list:
    print(item)
    key = item.split('\t')[0].lower()
    list_1.append(key)
print(list_1)
# Out:
# 35
# P-E-Type
# P-E-Cleaning
# P-E-Fittings
# P-E-Operation
# P-E-Function
# P-E-Visualization
# P-E-Effect
# P-E-Sound
# P-E-Packing
# P-E-Screen
# P-E-Size
# P-E-PriceMatch
# P-E-RelatedCategories
# P-C-Loyalty
# P-C-Use
# P-C-Price
# P-C-Quality
# P-C-Color
# P-C-Appearance
# P-C-Marketing
# P-C-Brand
# P-C-Origin
# P-C-Others
# CS-C-Attitude
# CS-C-Handling
# CS-C-Others
# L-C-Delivery
# L-C-Attitude
# L-C-Others
# S-C-Maintanence
# S-C-Return
# S-C-Exchange
# S-C-Warranty
# S-C-Refund
# S-C-Others
# ...

# %%
text="""P-E-Type	炸锅类型
P-E-Cleaning	清洗
P-E-Fittings	配件
P-E-Operation	操作
P-E-Function	炸锅功能
P-E-Visualization	可视化
P-E-Effect	炸锅效果
P-E-Sound	运转音
P-E-Packing	包装
P-E-Screen	显示
P-E-Size	尺寸
P-E-PriceMatch	价保
P-E-RelatedCategories	关联品类
P-C-Loyalty	商品复购
P-C-Use	商品用途
P-C-Price	商品价格
P-C-Quality	商品质量
P-C-Color	商品颜色
P-C-Appearance	商品外观
P-C-Marketing	商品营销
P-C-Brand	商品品牌
P-C-Origin	商品产地
P-C-Others	商品其他
CS-C-Attitude	客服态度
CS-C-Handling	客服处理速度
CS-C-Others	客服其他
L-C-Delivery	配送速度
L-C-Attitude	物流态度
L-C-Others	物流其他
S-C-Maintanence	维修服务
S-C-Return	退货服务
S-C-Exchange	换货服务
S-C-Warranty	质保
S-C-Refund	退款服务
S-C-Others	售后其他"""
print(len(text.split('\n')))
result_list = text.split('\n')

dict_1 = {}
for item in result_list:
    print(item)
    key = item.split('\t')[0].lower()
    value = item.split('\t')[1]
    dict_1[key] = value
print(dict_1)
# Out:
# 35
# P-E-Type	炸锅类型
# P-E-Cleaning	清洗
# P-E-Fittings	配件
# P-E-Operation	操作
# P-E-Function	炸锅功能
# P-E-Visualization	可视化
# P-E-Effect	炸锅效果
# P-E-Sound	运转音
# P-E-Packing	包装
# P-E-Screen	显示
# P-E-Size	尺寸
# P-E-PriceMatch	价保
# P-E-RelatedCategories	关联品类
# P-C-Loyalty	商品复购
# P-C-Use	商品用途
# P-C-Price	商品价格
# P-C-Quality	商品质量
# P-C-Color	商品颜色
# P-C-Appearance	商品外观
# P-C-Marketing	商品营销
# P-C-Brand	商品品牌
# P-C-Origin	商品产地
# P-C-Others	商品其他
# CS-C-Attitude	客服态度
# CS-C-Handling	客服处理速度
# CS-C-Others	客服其他
# L-C-Delivery	配送速度
# L-C-Attitude	物流态度
# L-C-Others	物流其他
# S-C-Maintanence	维修服务
# S-C-Return	退货服务
# S-C-Exchange	换货服务
# S-C-Warranty	质保
# S-C-Refund	退款服务
# S-C-Others	售后其他
# ...

# %%
text="""炸锅类型
清洗
配件
操作
炸锅功能
可视化
炸锅效果
运转音
包装
显示
尺寸
价保
关联品类
商品复购
商品用途
商品价格
商品质量
商品颜色
商品外观
商品营销
商品品牌
商品产地
商品其他
客服态度
客服处理速度
客服其他
配送速度
物流态度
物流其他
维修服务
退货服务
换货服务
质保
退款服务
售后其他"""
print(len(text.split('\n')))
print(text.split('\n'))
# Out:
# 35
# ['炸锅类型', '清洗', '配件', '操作', '炸锅功能', '可视化', '炸锅效果', '运转音', '包装', '显示', '尺寸', '价保', '关联品类', '商品复购', '商品用途', '商品价格', '商品质量', '商品颜色', '商品外观', '商品营销', '商品品牌', '商品产地', '商品其他', '客服态度', '客服处理速度', '客服其他', '配送速度', '物流态度', '物流其他', '维修服务', '退货服务', '换货服务', '质保', '退款服务', '售后其他']
